# %%
import numpy as np 
import pandas as pd 
from scipy import stats 
import seaborn as sns 
data= pd.read_csv('D:/CapStone Project/Dumb/Models/Diabetic Dataset/diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# This data does not contain any null values. So we don't need to worry about filling/dropping values.

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.duplicated()
data=data.drop_duplicates()
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# The data doesn't contain any duplicate values also. Hence we need not worry about them.

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# All bioparameters are in the range. Hence the data does not have observational/structural errors in them. Hence we need to worry about them.

# %%
for x in data.columns:
    z=np.abs(stats.zscore(data[x]))
    print(x+str(z))
# Out:
# Pregnancies0      0.639947
# 1      0.844885
# 2      1.233880
# 3      0.844885
# 4      1.141852
#          ...
# 763    1.827813
# 764    0.547919
# 765    0.342981
# 766    0.844885
# 767    0.844885
# Name: Pregnancies, Length: 768, dtype: float64
# Glucose0      0.848324
# 1      1.123396
# 2      1.943724
# 3      0.998208
# 4      0.504055
#          ...
# 763    0.622642
# 764    0.034598
# 765    0.003301
# 766    0.159787
# 767    0.873019
# Name: Glucose, Length: 768, dtype: float64
# BloodPressure0      0.149641
# 1      0.160546
# 2      0.263941
# 3      0.160546
# 4      1.504687
#          ...
# 763    0.356432
# 764    0.046245
# 765    0.149641
# 766    0.470732
# 767    0.046245
# Name: BloodPressure, Length: 768, dtype: float64
# SkinThickness0      0.907270
# 1      0.530902
# 2      1.288212
# 3      0.154533
# 4      0.907270
#          ...
# 763    1.722735
# 764    0.405445
# 765    0.154533
# 766    1.288212
# 767    0.656358
# Name: SkinThickness, Length: 768, dtype: float64
# Insulin0      0.692891
# 1      0.692891
# 2      0.692891
# 3      0.123302
# 4      0.765836
#          ...
# 763    0.870031
# 764    0.692891
# 765    0.279594
# 766    0.692891
# 767    0.692891
# Name: Insulin, Length: 768, dtype: float64
# BMI0      0.204013
# 1      0.684422
# 2      1.103255
# 3      0.494043
# 4      1.409746
#          ...
# 763    0.115169
# 764    0.610154
# 765    0.735190
# 766    0.240205
# 767    0.202129
# Name: BMI, Length: 768, dtype: float64
# DiabetesPedigreeFunction0      0.468492
# 1      0.365061
# 2      0.604397
# 3      0.920763
# 4      5.484909
#          ...
# 763    0.908682
# 764    0.398282
# 765    0.685193
# 766    0.371101
# 767    0.473785
# Name: DiabetesPedigreeFunction, Length: 768, dtype: float64
# Age0      1.425995
# 1      0.190672
# 2      0.105584
# 3      1.041549
# 4      0.020496
#          ...
# 763    2.532136
# 764    0.531023
# 765    0.275760
# 766    1.170732
# 767    0.871374
# Name: Age, Length: 768, dtype: float64
# Outcome0      1.365896
# 1      0.732120
# 2      1.365896
# 3      0.732120
# 4      1.365896
#          ...
# 763    0.732120
# 764    0.732120
# 765    0.732120
# 766    1.365896
# 767    0.732120
# Name: Outcome, Length: 768, dtype: float64

# %% [markdown]
# The next step is feature scaling. I am doing a comparison of ML and DL for this dataset. For ML, i am considering SVM, which is a distance based algorithm. Hence normalization of data would be appropriate. On the other hand, for DL I am considering ANN, which is gradient descent based algorithm for which standardisation of data would be appropriate, since it can help in faster identification of local minima.

# %%
data_norm=data.copy()
for column in data.columns:
    data_norm[column] = (data_norm[column] - data_norm[column].min()) / (data_norm[column].max() - data_norm[column].min()) 
data_norm.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1     0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2     0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3     0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4     0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.234415  0.483333      1.0
# 1                  0.116567  0.166667      0.0
# 2                  0.253629  0.183333      1.0
# 3                  0.038002  0.000000      0.0
# 4                  0.943638  0.200000      1.0

# %%
lis=['Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Pregnancies']
def standartization(x):
    x_std = x.copy(deep=True)
    for column in lis:
        x_std[column] = (x_std[column] - x_std[column].mean()) / x_std[column].std() 
    return x_std

data= standartization(data)
data.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.639530  0.847771       0.149543       0.906679 -0.692439  0.203880
# 1    -0.844335 -1.122665      -0.160441       0.530556 -0.692439 -0.683976
# 2     1.233077  1.942458      -0.263769      -1.287373 -0.692439 -1.102537
# 3    -0.844335 -0.997558      -0.160441       0.154433  0.123221 -0.493721
# 4    -1.141108  0.503727      -1.503707       0.906679  0.765337  1.408828
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.468187  1.425067        1
# 1                 -0.364823 -0.190548        0
# 2                  0.604004 -0.105515        1
# 3                 -0.920163 -1.040871        0
# 4                  5.481337 -0.020483        1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    float64
#  1   Glucose                   768 non-null    float64
#  2   BloodPressure             768 non-null    float64
#  3   SkinThickness             768 non-null    float64
#  4   Insulin                   768 non-null    float64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    float64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(8), int64(1)
# memory usage: 60.0 KB

# %%
data['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
y=data['Outcome']
x=data.drop(['Outcome'],axis=1)

# %%
yn=data_norm['Outcome']
xn=data_norm.drop(['Outcome'],axis=1)

# %% [markdown]
# I am creating separate train and test sets for standardised and normalised data. the ones having n as suffix are normalised.

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.15,stratify=y)
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (652, 8)
# (116, 8)
# (652,)
# (116,)

# %%
from sklearn.model_selection import train_test_split
xntrain,xntest,yntrain,yntest= train_test_split(xn,yn,test_size=0.15,stratify=y)
print(xntrain.shape)
print(xntest.shape)
print(yntrain.shape)
print(yntest.shape)
# Out:
# (652, 8)
# (116, 8)
# (652,)
# (116,)

# %%
from sklearn.svm import SVC
svm_model= SVC(kernel='rbf',gamma=8)
svm_model.fit(xntrain,yntrain)
# Out:
# SVC(gamma=8)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
predictions= svm_model.predict(xntrain)
percentage=svm_model.score(xntrain,yntrain)
res=confusion_matrix(yntrain,predictions)
print("Training confusion matrix")
print(res)
predictions= svm_model.predict(xntest)
percentage=svm_model.score(xntest,yntest)
res=confusion_matrix(yntest,predictions)
print("validation confusion matrix")
print(res)
print(classification_report(ytest, predictions))
# check the accuracy on the training set
print('training accuracy = '+str(svm_model.score(xntrain, yntrain)*100))
print('testing accuracy = '+str(svm_model.score(xntest, yntest)*100))
# Out:
# Training confusion matrix
# [[400  24]
#  [ 71 157]]
# validation confusion matrix
# [[66 10]
#  [16 24]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.68      0.66        76
#            1       0.29      0.25      0.27        40
#
#     accuracy                           0.53       116
#    macro avg       0.46      0.47      0.46       116
# weighted avg       0.52      0.53      0.52       116
#
# training accuracy = 85.42944785276073
# testing accuracy = 77.58620689655173

# %% [markdown]
# I trained the SVM without feature scaling and with standardisation. It produced test acc of 55% and 62% for no feature scaling and with standardisation. Hence normalisation is good for distance based algorithms like SVM.

# %% [markdown]
# For the DL part, I am considering ANN, comprising of 2 layers of 256 neurons as hidden layers. Considering more neurons and layers resulted in overfitting. Hence i limited with this hyperparameters. It was compiled using adam optimiser and crossentropy loss function.

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
dl_model = Sequential() 

dl_model.add(Dense(256,  activation = 'relu' ,input_shape=([8]))) #input layer
dl_model.add(Dense(256,  activation = 'relu'))
dl_model.add(Dense(1,activation = 'sigmoid'))
dl_model.summary()
dl_model.compile(optimizer = 'adam' , loss = 'binary_crossentropy' ,metrics = ['accuracy','Precision','Recall','AUC'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               2304
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 68,353
# Trainable params: 68,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 50
history = dl_model.fit(xtrain ,
                    ytrain ,
                    epochs= num_epochs ,
                    steps_per_epoch=200,
                    validation_data=(xtest ,ytest))
# Out:
# Epoch 1/50
# 200/200 [==============================] - 2s 4ms/step - loss: 0.4946 - accuracy: 0.7688 - precision: 0.6907 - recall: 0.5927 - auc: 0.8164 - val_loss: 0.5133 - val_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 0.5500 - val_auc: 0.8049
# Epoch 2/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4709 - accuracy: 0.7688 - precision: 0.6975 - recall: 0.5950 - auc: 0.8364 - val_loss: 0.5160 - val_accuracy: 0.7241 - val_precision: 0.6429 - val_recall: 0.4500 - val_auc: 0.8008
# Epoch 3/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4420 - accuracy: 0.7937 - precision: 0.7481 - recall: 0.6644 - auc: 0.8620 - val_loss: 0.4887 - val_accuracy: 0.7155 - val_precision: 0.6061 - val_recall: 0.5000 - val_auc: 0.8289
# Epoch 4/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4263 - accuracy: 0.8087 - precision: 0.7436 - recall: 0.6517 - auc: 0.8620 - val_loss: 0.5116 - val_accuracy: 0.7241 - val_precision: 0.6250 - val_recall: 0.5000 - val_auc: 0.8105
# Epoch 5/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4143 - accuracy: 0.8025 - precision: 0.7431 - recall: 0.6690 - auc: 0.8753 - val_loss: 0.5122 - val_accuracy: 0.7241 - val_precision: 0.6053 - val_recall: 0.5750 - val_auc: 0.8118
# Epoch 6/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4061 - accuracy: 0.8150 - precision: 0.7673 - recall: 0.6738 - auc: 0.8804 - val_loss: 0.5395 - val_accuracy: 0.7328 - val_precision: 0.6098 - val_recall: 0.6250 - val_auc: 0.8148
# Epoch 7/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3993 - accuracy: 0.8163 - precision: 0.7642 - recall: 0.6787 - auc: 0.8833 - val_loss: 0.5600 - val_accuracy: 0.7241 - val_precision: 0.6176 - val_recall: 0.5250 - val_auc: 0.7965
# Epoch 8/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3761 - accuracy: 0.8200 - precision: 0.7736 - recall: 0.7093 - auc: 0.9019 - val_loss: 0.5546 - val_accuracy: 0.7069 - val_precision: 0.6250 - val_recall: 0.3750 - val_auc: 0.8211
# Epoch 9/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3881 - accuracy: 0.8163 - precision: 0.7759 - recall: 0.6679 - auc: 0.8916 - val_loss: 0.5987 - val_accuracy: 0.7414 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.7822
# Epoch 10/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3583 - accuracy: 0.8363 - precision: 0.8083 - recall: 0.6953 - auc: 0.9105 - val_loss: 0.5847 - val_accuracy: 0.7241 - val_precision: 0.5952 - val_recall: 0.6250 - val_auc: 0.8099
# Epoch 11/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3628 - accuracy: 0.8400 - precision: 0.8022 - recall: 0.7414 - auc: 0.9094 - val_loss: 0.6029 - val_accuracy: 0.6810 - val_precision: 0.5405 - val_recall: 0.5000 - val_auc: 0.7727
# Epoch 12/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3295 - accuracy: 0.8537 - precision: 0.8235 - recall: 0.7232 - auc: 0.9221 - val_loss: 0.6437 - val_accuracy: 0.7155 - val_precision: 0.5897 - val_recall: 0.5750 - val_auc: 0.7956
# Epoch 13/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3335 - accuracy: 0.8438 - precision: 0.7882 - recall: 0.7390 - auc: 0.9194 - val_loss: 0.6061 - val_accuracy: 0.7241 - val_precision: 0.6333 - val_recall: 0.4750 - val_auc: 0.7947
# Epoch 14/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3131 - accuracy: 0.8575 - precision: 0.8359 - recall: 0.7552 - auc: 0.9330 - val_loss: 0.6061 - val_accuracy: 0.6983 - val_precision: 0.5641 - val_recall: 0.5500 - val_auc: 0.8064
# Epoch 15/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3171 - accuracy: 0.8612 - precision: 0.8292 - recall: 0.7398 - auc: 0.9248 - val_loss: 0.6782 - val_accuracy: 0.7155 - val_precision: 0.5854 - val_recall: 0.6000 - val_auc: 0.7747
# Epoch 16/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2729 - accuracy: 0.8825 - precision: 0.8577 - recall: 0.8103 - auc: 0.9511 - val_loss: 0.6617 - val_accuracy: 0.7069 - val_precision: 0.6000 - val_recall: 0.4500 - val_auc: 0.7819
# Epoch 17/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2925 - accuracy: 0.8800 - precision: 0.8601 - recall: 0.7712 - auc: 0.9369 - val_loss: 0.7312 - val_accuracy: 0.7241 - val_precision: 0.6053 - val_recall: 0.5750 - val_auc: 0.7887
# Epoch 18/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2645 - accuracy: 0.8813 - precision: 0.8464 - recall: 0.8071 - auc: 0.9538 - val_loss: 0.6796 - val_accuracy: 0.7069 - val_precision: 0.6000 - val_recall: 0.4500 - val_auc: 0.7844
# Epoch 19/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2475 - accuracy: 0.8925 - precision: 0.8880 - recall: 0.8014 - auc: 0.9592 - val_loss: 0.7255 - val_accuracy: 0.6810 - val_precision: 0.5385 - val_recall: 0.5250 - val_auc: 0.7753
# Epoch 20/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2356 - accuracy: 0.9062 - precision: 0.8919 - recall: 0.8309 - auc: 0.9632 - val_loss: 0.7428 - val_accuracy: 0.6724 - val_precision: 0.5278 - val_recall: 0.4750 - val_auc: 0.7768
# Epoch 21/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2369 - accuracy: 0.8988 - precision: 0.8930 - recall: 0.7978 - auc: 0.9619 - val_loss: 0.8696 - val_accuracy: 0.6552 - val_precision: 0.5000 - val_recall: 0.4750 - val_auc: 0.7373
# Epoch 22/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2200 - accuracy: 0.9112 - precision: 0.8963 - recall: 0.8491 - auc: 0.9684 - val_loss: 0.7612 - val_accuracy: 0.6983 - val_precision: 0.5758 - val_recall: 0.4750 - val_auc: 0.7715
# Epoch 23/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2052 - accuracy: 0.9212 - precision: 0.9317 - recall: 0.8345 - auc: 0.9725 - val_loss: 0.8264 - val_accuracy: 0.6897 - val_precision: 0.5588 - val_recall: 0.4750 - val_auc: 0.7516
# Epoch 24/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1836 - accuracy: 0.9350 - precision: 0.9257 - recall: 0.8861 - auc: 0.9794 - val_loss: 0.8607 - val_accuracy: 0.6897 - val_precision: 0.5588 - val_recall: 0.4750 - val_auc: 0.7734
# Epoch 25/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1885 - accuracy: 0.9237 - precision: 0.9280 - recall: 0.8436 - auc: 0.9768 - val_loss: 0.9043 - val_accuracy: 0.6897 - val_precision: 0.5476 - val_recall: 0.5750 - val_auc: 0.7513
# Epoch 26/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1663 - accuracy: 0.9375 - precision: 0.9253 - recall: 0.8997 - auc: 0.9833 - val_loss: 0.9205 - val_accuracy: 0.6983 - val_precision: 0.5862 - val_recall: 0.4250 - val_auc: 0.7564
# Epoch 27/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1647 - accuracy: 0.9413 - precision: 0.9382 - recall: 0.8869 - auc: 0.9830 - val_loss: 0.8973 - val_accuracy: 0.7069 - val_precision: 0.5882 - val_recall: 0.5000 - val_auc: 0.7589
# Epoch 28/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1682 - accuracy: 0.9350 - precision: 0.9370 - recall: 0.8785 - auc: 0.9833 - val_loss: 0.9543 - val_accuracy: 0.6810 - val_precision: 0.5455 - val_recall: 0.4500 - val_auc: 0.7664
# Epoch 29/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1490 - accuracy: 0.9488 - precision: 0.9498 - recall: 0.8978 - auc: 0.9872 - val_loss: 1.0702 - val_accuracy: 0.6897 - val_precision: 0.5625 - val_recall: 0.4500 - val_auc: 0.7265
# Epoch 30/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1241 - accuracy: 0.9538 - precision: 0.9552 - recall: 0.9110 - auc: 0.9918 - val_loss: 1.0496 - val_accuracy: 0.6897 - val_precision: 0.5526 - val_recall: 0.5250 - val_auc: 0.7456
# Epoch 31/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1159 - accuracy: 0.9663 - precision: 0.9698 - recall: 0.9312 - auc: 0.9938 - val_loss: 1.1071 - val_accuracy: 0.6897 - val_precision: 0.5556 - val_recall: 0.5000 - val_auc: 0.7554
# Epoch 32/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0964 - accuracy: 0.9712 - precision: 0.9704 - recall: 0.9458 - auc: 0.9964 - val_loss: 1.1886 - val_accuracy: 0.6724 - val_precision: 0.5294 - val_recall: 0.4500 - val_auc: 0.7334
# Epoch 33/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0963 - accuracy: 0.9700 - precision: 0.9644 - recall: 0.9509 - auc: 0.9959 - val_loss: 1.1791 - val_accuracy: 0.6897 - val_precision: 0.5625 - val_recall: 0.4500 - val_auc: 0.7651
# Epoch 34/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.1039 - accuracy: 0.9650 - precision: 0.9776 - recall: 0.9225 - auc: 0.9951 - val_loss: 1.2722 - val_accuracy: 0.6810 - val_precision: 0.5385 - val_recall: 0.5250 - val_auc: 0.7650
# Epoch 35/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0868 - accuracy: 0.9675 - precision: 0.9733 - recall: 0.9307 - auc: 0.9972 - val_loss: 1.3674 - val_accuracy: 0.6810 - val_precision: 0.5333 - val_recall: 0.6000 - val_auc: 0.7559
# Epoch 36/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0888 - accuracy: 0.9762 - precision: 0.9811 - recall: 0.9489 - auc: 0.9944 - val_loss: 1.1615 - val_accuracy: 0.7241 - val_precision: 0.6053 - val_recall: 0.5750 - val_auc: 0.7916
# Epoch 37/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0665 - accuracy: 0.9812 - precision: 0.9852 - recall: 0.9604 - auc: 0.9985 - val_loss: 1.2939 - val_accuracy: 0.7069 - val_precision: 0.5938 - val_recall: 0.4750 - val_auc: 0.7516
# Epoch 38/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0648 - accuracy: 0.9800 - precision: 0.9756 - recall: 0.9689 - auc: 0.9987 - val_loss: 1.4178 - val_accuracy: 0.6897 - val_precision: 0.5500 - val_recall: 0.5500 - val_auc: 0.7327
# Epoch 39/50
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0586 - accuracy: 0.9862 - precision: 0.9926 - recall: 0.9676 - auc: 0.9986 - val_loss: 1.4487 - val_accuracy: 0.7069 - val_precision: 0.5750 - val_recall: 0.5750 - val_auc: 0.7387
# Epoch 40/50
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0732 - accuracy: 0.9775 - precision: 0.9708 - recall: 0.9638 - auc: 0.9968 - val_loss: 1.4944 - val_accuracy: 0.7069 - val_precision: 0.5833 - val_recall: 0.5250 - val_auc: 0.7437
# Epoch 41/50
# 148/200 [=====================>........] - ETA: 0s - loss: 0.0963 - accuracy: 0.9713 - precision: 0.9575 - recall: 0.9621 - auc: 0.9935WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 10000 batches). You may need to use the repeat() function when building your dataset.
# 200/200 [==============================] - 1s 7ms/step - loss: 0.0951 - accuracy: 0.9717 - precision: 0.9579 - recall: 0.9624 - auc: 0.9937 - val_loss: 1.3174 - val_accuracy: 0.7500 - val_precision: 0.6410 - val_recall: 0.6250 - val_auc: 0.7992

# %%
dl_model.evaluate(xtrain,ytrain)
# Out:
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0544 - accuracy: 0.9893 - precision: 0.9911 - recall: 0.9781 - auc: 0.9987
# [0.05436102673411369,
#  0.9892638325691223,
#  0.9911110997200012,
#  0.9780701994895935,
#  0.9987276792526245]

# %%
dl_model.evaluate(xtest,ytest)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3174 - accuracy: 0.7500 - precision: 0.6410 - recall: 0.6250 - auc: 0.7992
# [1.3174365758895874, 0.75, 0.6410256624221802, 0.625, 0.7991775870323181]

# %% [markdown]
# As you can see, the ANN produced 68% test accuracy which is way less than SVM. Hence we can say that the ML algorithm produced well than that of DL algorithm. Can we stop with this conclusion or are we missing something??

# %%
print(data['Outcome'].value_counts())
df_class_0 = data[data['Outcome'] == 0]
df_class_1 = data[data['Outcome'] == 1]
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# As you can see, there is class imbalance, the amount of diabetes negative is twice than that of diabetes positive. In this scenario, we cant compare the performance of algorithms based on accuracy. So to overcome the class imbalance I oversampled the minority class to the samples of majority class (500). So the total data consits of 1000 samples with equal distribution. I repeated this process for the standardised and normalized datasets.

# %%
print(data_norm['Outcome'].value_counts())
df_n_class_0 = data_norm[data_norm['Outcome'] == 0]
df_n_class_1 = data_norm[data_norm['Outcome'] == 1]
# Out:
# 0.0    500
# 1.0    268
# Name: Outcome, dtype: int64

# %%
df_class_1_over = df_class_1.sample(500, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)
df_test_over.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 227
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               1000 non-null   float64
#  1   Glucose                   1000 non-null   float64
#  2   BloodPressure             1000 non-null   float64
#  3   SkinThickness             1000 non-null   float64
#  4   Insulin                   1000 non-null   float64
#  5   BMI                       1000 non-null   float64
#  6   DiabetesPedigreeFunction  1000 non-null   float64
#  7   Age                       1000 non-null   float64
#  8   Outcome                   1000 non-null   int64
# dtypes: float64(8), int64(1)
# memory usage: 78.1 KB

# %%
df_n_class_1_over = df_n_class_1.sample(500, replace=True)
df_test_n_over = pd.concat([df_n_class_0, df_n_class_1_over], axis=0)
df_test_n_over.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 11
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               1000 non-null   float64
#  1   Glucose                   1000 non-null   float64
#  2   BloodPressure             1000 non-null   float64
#  3   SkinThickness             1000 non-null   float64
#  4   Insulin                   1000 non-null   float64
#  5   BMI                       1000 non-null   float64
#  6   DiabetesPedigreeFunction  1000 non-null   float64
#  7   Age                       1000 non-null   float64
#  8   Outcome                   1000 non-null   float64
# dtypes: float64(9)
# memory usage: 78.1 KB

# %%
y1=df_test_over['Outcome']
df_test_over=df_test_over.drop(['Outcome'],axis=1)
X1=df_test_over

# %%
y1n=df_test_n_over['Outcome']
df_test_n_over=df_test_n_over.drop(['Outcome'],axis=1)
X1n=df_test_n_over

# %% [markdown]
# The rest of the parameters are the same. This includes the train test split ratio and the algorithm parameters. Now the SVM and ANN are trained using the upsampled datasets. The same as before, normalized dataset for SVM and standardized dataset for ANN.

# %%
from sklearn.model_selection import train_test_split

X1_s_train,X1_s_test ,y1_s_train, y1_s_test = train_test_split(X1,y1,
                                                   test_size=0.2,
                                                   random_state=0,
                                                  shuffle = True,
                                                  stratify = y1)

print('training data shape is :{}.'.format(X1_s_train.shape))
print('training label shape is :{}.'.format(y1_s_train.shape))
print('testing data shape is :{}.'.format(X1_s_test.shape))
print('testing label shape is :{}.'.format(y1_s_test.shape))
# Out:
# training data shape is :(800, 8).
# training label shape is :(800,).
# testing data shape is :(200, 8).
# testing label shape is :(200,).

# %%
from sklearn.model_selection import train_test_split

X1_s_n_train,X1_s_n_test ,y1_s_n_train, y1_s_n_test = train_test_split(X1n,y1n,
                                                   test_size=0.2,
                                                   random_state=0,
                                                  shuffle = True,
                                                  stratify = y1n)

print('training data shape is :{}.'.format(X1_s_n_train.shape))
print('training label shape is :{}.'.format(y1_s_n_train.shape))
print('testing data shape is :{}.'.format(X1_s_n_test.shape))
print('testing label shape is :{}.'.format(y1_s_n_test.shape))
# Out:
# training data shape is :(800, 8).
# training label shape is :(800,).
# testing data shape is :(200, 8).
# testing label shape is :(200,).

# %%
from sklearn.svm import SVC
svc_s_model = SVC(kernel='rbf',gamma=8)
svc_s_model.fit(X1_s_n_train, y1_s_n_train)
# Out:
# SVC(gamma=8)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
predictions= svc_s_model.predict(X1_s_n_train)
percentage=svc_s_model.score(X1_s_n_train,y1_s_n_train)
res=confusion_matrix(y1_s_n_train,predictions)
print("Training confusion matrix")
print(res)
predictions= svc_s_model.predict(X1_s_n_test)
percentage=svc_s_model.score(X1_s_n_test,y1_s_n_test)
res=confusion_matrix(y1_s_n_test,predictions)
print("validation confusion matrix")
print(res)
print(classification_report(y1_s_n_test, predictions))
# check the accuracy on the training set
print('training accuracy = '+str(svc_s_model.score(X1_s_n_train, y1_s_n_train)*100))
print('testing accuracy = '+str(svc_s_model.score(X1_s_n_test, y1_s_n_test)*100))
# Out:
# Training confusion matrix
# [[327  73]
#  [ 49 351]]
# validation confusion matrix
# [[82 18]
#  [20 80]]
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.82      0.81       100
#          1.0       0.82      0.80      0.81       100
#
#     accuracy                           0.81       200
#    macro avg       0.81      0.81      0.81       200
# weighted avg       0.81      0.81      0.81       200
#
# training accuracy = 84.75
# testing accuracy = 81.0

# %%
from sklearn.metrics import classification_report
print(classification_report(y1_s_n_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.82      0.81       100
#          1.0       0.82      0.80      0.81       100
#
#     accuracy                           0.81       200
#    macro avg       0.81      0.81      0.81       200
# weighted avg       0.81      0.81      0.81       200
